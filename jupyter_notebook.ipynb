# %%
import pandas as pd

# %%
df = pd.DataFrame({
                   'isim': ['sercan', 'ahmet', 'mehmet', 'ayşe', 'selin', 'ceren'],
                   'yas': [24, 25, 26, 27, 28, 29],
                   'cinsiyet': ['E', 'E', 'E', 'K', 'K', 'K'],
                   'maas': [3000, 4500, 3500, 4000, 5500, 3500]
                  }
                 )

# %%
df.tail()
# Out:
#      isim  yas cinsiyet  maas
# 1   ahmet   25        E  4500
# 2  mehmet   26        E  3500
# 3    ayşe   27        K  4000
# 4   selin   28        K  5500
# 5   ceren   29        K  3500

# %%
df.shape
# Out:
# (6, 4)

# %%
df["isim"] # SELECT isim FROM table_name
# Out:
# 0    sercan
# 1     ahmet
# 2    mehmet
# 3      ayşe
# 4     selin
# 5     ceren
# Name: isim, dtype: object

# %%
df[["isim","yas"]] # SELECT isim,yas FROM table_name
# Out:
#      isim  yas
# 0  sercan   24
# 1   ahmet   25
# 2  mehmet   26
# 3    ayşe   27
# 4   selin   28
# 5   ceren   29

# %%
df[["isim","yas"]].where(df["maas"]>4000)
# Out:
#     isim   yas
# 0    NaN   NaN
# 1  ahmet  25.0
# 2    NaN   NaN
# 3    NaN   NaN
# 4  selin  28.0
# 5    NaN   NaN

# %%
df["yas"].max() # SELECT MAX(yas) FROM table_name
# Out:
# 29

# %%
df.describe()
# Out:
#              yas         maas
# count   6.000000     6.000000
# mean   26.500000  4000.000000
# std     1.870829   894.427191
# min    24.000000  3000.000000
# 25%    25.250000  3500.000000
# 50%    26.500000  3750.000000
# 75%    27.750000  4375.000000
# max    29.000000  5500.000000

# %%
df['sehir'] = ['istanbul', 'istanbul', 'ankara', 'izmir', 'istanbul', 'ankara']

# %%
df
# Out:
#      isim  yas cinsiyet  maas     sehir
# 0  sercan   24        E  3000  istanbul
# 1   ahmet   25        E  4500  istanbul
# 2  mehmet   26        E  3500    ankara
# 3    ayşe   27        K  4000     izmir
# 4   selin   28        K  5500  istanbul
# 5   ceren   29        K  3500    ankara

# %%
df['yas_1'] = df['yas'] + 1

# %%
df # SELECT yas + 1 as yas_1 FROM table_name
# Out:
#      isim  yas cinsiyet  maas     sehir  yas_1
# 0  sercan   24        E  3000  istanbul     25
# 1   ahmet   25        E  4500  istanbul     26
# 2  mehmet   26        E  3500    ankara     27
# 3    ayşe   27        K  4000     izmir     28
# 4   selin   28        K  5500  istanbul     29
# 5   ceren   29        K  3500    ankara     30

# %%
df = df.drop(columns = ['yas_1'],axis=1)

# %%
df
# Out:
#      isim  yas cinsiyet  maas     sehir
# 0  sercan   24        E  3000  istanbul
# 1   ahmet   25        E  4500  istanbul
# 2  mehmet   26        E  3500    ankara
# 3    ayşe   27        K  4000     izmir
# 4   selin   28        K  5500  istanbul
# 5   ceren   29        K  3500    ankara

# %%
df.groupby('sehir')

# %%
df.groupby('sehir').agg({'maas': 'mean'}) # SELECT sehir,avg(maas) AS Ortalama_Maas FROM table_name GROUP BY sehir
# Out:
#                  maas
# sehir
# ankara    3500.000000
# istanbul  4333.333333
# izmir     4000.000000

# %%
df.groupby('cinsiyet').agg({'maas': 'mean'})
# Out:
#                  maas
# cinsiyet
# E         3666.666667
# K         4333.333333

# %%
df.groupby('sehir').agg({'maas': 'max'})
# Out:
#           maas
# sehir
# ankara    3500
# istanbul  5500
# izmir     4000

# %%
df
# Out:
#      isim  yas cinsiyet  maas     sehir
# 0  sercan   24        E  3000  istanbul
# 1   ahmet   25        E  4500  istanbul
# 2  mehmet   26        E  3500    ankara
# 3    ayşe   27        K  4000     izmir
# 4   selin   28        K  5500  istanbul
# 5   ceren   29        K  3500    ankara

# %%
df.sort_values('maas',ascending=False) # SELECT * FROM table_name ORDER BY maas DESC;
# Out:
#      isim  yas cinsiyet  maas     sehir
# 4   selin   28        K  5500  istanbul
# 1   ahmet   25        E  4500  istanbul
# 3    ayşe   27        K  4000     izmir
# 2  mehmet   26        E  3500    ankara
# 5   ceren   29        K  3500    ankara
# 0  sercan   24        E  3000  istanbul

# %%
<df.loc[df['cinsiyet'] == 'K'] # SELECT * FROM table_name WHERE cinsiyet = "K"
# Out:
#     isim  yas cinsiyet  maas     sehir
# 3   ayşe   27        K  4000     izmir
# 4  selin   28        K  5500  istanbul
# 5  ceren   29        K  3500    ankara

# %%
df.loc[(df["sehir"]=="istanbul") & (df["yas"]>=28)]
# Out:
#     isim  yas cinsiyet  maas     sehir
# 4  selin   28        K  5500  istanbul

# %%
df
# Out:
#      isim  yas cinsiyet  maas     sehir
# 0  sercan   24        E  3000  istanbul
# 1   ahmet   25        E  4500  istanbul
# 2  mehmet   26        E  3500    ankara
# 3    ayşe   27        K  4000     izmir
# 4   selin   28        K  5500  istanbul
# 5   ceren   29        K  3500    ankara

# %%
df.iloc[0:3]
# Out:
#      isim  yas cinsiyet  maas     sehir
# 0  sercan   24        E  3000  istanbul
# 1   ahmet   25        E  4500  istanbul
# 2  mehmet   26        E  3500    ankara

# %%
df = pd.read_csv("../Fenerbahce-Project/Fenerbahce_Dataset03.csv")

# %%
df.loc[(df["Statu"]=="Gelenler") & (df["Position"]=="FOR")]
# Out:
#          PlayerName Position  Age               Club         Price  \
# 0      M. Batshuayi      FOR   29            Chelsea  3.5 milyon €
# 6        João Pedro      FOR   30    Cagliari Calcio  4.7 milyon €
# 8          T. Çukur      FOR   19         Watford FC             -
# 9           J. King      FOR   30         Watford FC             -
# 13  A. Sayyadmanesh      FOR   21     Hull City AFC              -
# 16         D. Rossi      FOR   24        Los Angeles  5.5 milyon €
# 18    Gülhan Üreyen      FOR   20         İnegölspor             -
# 20            Bruma      FOR   28      PSV Eindhoven             -
# 22       M. Samatta      FOR   29  Royal Antwerp FC              -
#
#           Date         TransferInfo     Statu
# 0   02/09/2022             Transfer  Gelenler
# 6   21/07/2022             Transfer  Gelenler
# 8   13/07/2022             Transfer  Gelenler
# 9   13/07/2022     Serbest Transfer  Gelenler
# 13  01/07/2022       Kiralık Dönüşü  Gelenler
# ...

# %%
df
# Out:
#              PlayerName Position  Age                                Club  \
# 0          M. Batshuayi      FOR   29                             Chelsea
# 1   İrfan Can Eğribayat      KAL   24                             Göztepe
# 2            E. Alioski      DEF   30                    Al Ahli (Jeddah)
# 3            Luan Peres      DEF   28                 Olympique Marseille
# 4      Gustavo Henrique      DEF   29                         CR Flamengo
# 5              L. Diack      ORT   21                  Tuzla Spor Kulübü
# 6            João Pedro      FOR   30                     Cagliari Calcio
# 7          Willian Arão      ORT   30                         CR Flamengo
# 8              T. Çukur      FOR   19                          Watford FC
# 9               J. King      FOR   30                          Watford FC
# 10             Emre Mor      ORT   25                          Karagümrük
# 11             M. Lemos      DEF   26                        KFCO Wilrijk
# ...

# %%
df.head(n=10)
# Out:
#             PlayerName Position  Age                 Club         Price  \
# 0         M. Batshuayi      FOR   29              Chelsea  3.5 milyon €
# 1  İrfan Can Eğribayat      KAL   24              Göztepe             -
# 2           E. Alioski      DEF   30     Al Ahli (Jeddah)             -
# 3           Luan Peres      DEF   28  Olympique Marseille  5.2 milyon €
# 4     Gustavo Henrique      DEF   29          CR Flamengo             -
# 5             L. Diack      ORT   21   Tuzla Spor Kulübü              -
# 6           João Pedro      FOR   30      Cagliari Calcio  4.7 milyon €
# 7         Willian Arão      ORT   30          CR Flamengo             -
# 8             T. Çukur      FOR   19           Watford FC             -
# 9              J. King      FOR   30           Watford FC             -
#
#          Date         TransferInfo     Statu
# 0  02/09/2022             Transfer  Gelenler
# 1  03/08/2022  Kiralık(30/06/2023)  Gelenler
# ...

# %%
max_age = df["Age"].max()

# %%
df.loc[df["Age"]==max_age] # SELECT TOP 1 * FROM table_name ORDER BY Age DESC
# Out:
#    PlayerName Position  Age                     Club Price        Date  \
# 36  José Sosa      ORT   37  Club Estudiantes de La      -  09/08/2022
#
#         TransferInfo     Statu
# 36  Serbest Transfer  Gidenler

# %%
# SELECT * FROM table_name WHERE Age = (SELECT MAX(Age) FROM table_name);
